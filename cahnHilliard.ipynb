# %%
# Fix MPI/OFI finalization errors on macOS
import os

os.environ["FI_PROVIDER"] = "tcp"
os.environ["MPICH_OFI_STARTUP_CONNECT"] = "0"


from mpi4py import MPI
import numpy as np
import matplotlib.pyplot as plt


from petsc4py.PETSc import ScalarType
from dolfinx import mesh, fem, plot, io, la

from basix.ufl import element, mixed_element


from dolfinx.fem.petsc import NonlinearProblem

import ufl
from ufl import grad, inner, dx
import time

import pyvista
import pyvistaqt


# Mesh
msh = mesh.create_rectangle(
    comm=MPI.COMM_WORLD,
    points=((0.0, 0.0), (1.0, 1.0)),
    n=(64, 64),
    cell_type=mesh.CellType.triangle,
)

dt = 0.001
num_time_steps = 100
t = 0
eps = 0.01
m = 1

# Function space
P1 = element("Lagrange", msh.basix_cell(), 1)

V = fem.functionspace(msh, mixed_element([P1,P1]))

v, w = ufl.TestFunction(V)

u = fem.Function(V)
u_old = fem.Function(V)
phi, mu = ufl.split(u)
phi_old, mu_old = ufl.split(u_old)

def doublewell(p):
    return 1/4*(1-p**2)**2

def doublewell_prime(p):
    return -(1-p**2)*p

rng = np.random.default_rng(42)
u.sub(0).interpolate(lambda x: rng.random(x.shape[1]).clip(-0.5,0.5))
u.x.scatter_forward()

# Variational form
F_phi = (ufl.inner(phi, v)  + eps*m*dt * ufl.inner(ufl.grad(mu), ufl.grad(v)) - ufl.inner(phi_old, v))*ufl.dx
F_mu = (ufl.inner(mu, w) - ufl.inner(doublewell_prime(phi), w)/eps - ufl.inner(ufl.grad(phi), grad(w))*eps)*dx

F = F_phi +F_mu

# Problem
problem = NonlinearProblem(
    F,
    u,
    petsc_options_prefix="ch_",
    petsc_options={
        "snes_type": "newtonls",
        "snes_linesearch_type": "none",
        "snes_stol": 1e-3,
        "snes_atol": 0,
        "snes_rtol": 0,
        "snes_max_it": 100,
        "snes_monitor": None,
        "ksp_type": "preonly",
        "pc_type": "lu",
        "ksp_error_if_not_converged": True,
    },
)


###############################
# Plotting with pyvista
###############################

V_phi, dofs = V.sub(0).collapse()

cells, types, x = plot.vtk_mesh(V_phi)
grid = pyvista.UnstructuredGrid(cells, types, x)
grid.point_data["phi"] = u.x.array[dofs].real
grid.set_active_scalars("phi")

p = pyvistaqt.BackgroundPlotter(title="phi", auto_update=True)
p.add_mesh(grid, clim =[0, 1])
p.view_xy(negative = True)
p.add_text(f"time: {t}", font_size=12, name="timelabel")


for i in range(num_time_steps):
    t += dt  # Update the time constant
    u_old.x.array[:] = u.x.array
    u_old.x.scatter_forward()
    u = problem.solve()
    u.x.scatter_forward()
    # l2_error = np.sqrt(
    # fem.assemble_scalar(fem.form(ufl.inner(uh - u_exact, uh - u_exact) * ufl.dx))
    # )
    # print(l2_error)
    # Add scalar data to grid
    p.add_text(f"time: {t:.2e}", font_size=12, name="timelabel")
    grid.point_data["phi"] = u.x.array[dofs].real
    p.app.processEvents()
    # time.sleep(0.1)
# Out:
# ld: warning: duplicate -rpath '/Users/wilhelmfaerden/miniforge3/envs/fenicsx-env/lib' ignored
# ld: warning: duplicate -rpath '/Users/wilhelmfaerden/miniforge3/envs/fenicsx-env/lib' ignored
# ld: warning: duplicate -rpath '/Users/wilhelmfaerden/miniforge3/envs/fenicsx-env/lib' ignored
# ld: warning: duplicate -rpath '/Users/wilhelmfaerden/miniforge3/envs/fenicsx-env/lib' ignored
#   0 SNES Function norm 6.292643241443e-01
#   1 SNES Function norm 8.107008602711e+01
#   2 SNES Function norm 1.234417224776e+04
#   0 SNES Function norm 1.234417224822e+04
#   1 SNES Function norm 3.656138328417e+03
#   2 SNES Function norm 1.082556985369e+03
#   3 SNES Function norm 3.200545240169e+02
#   4 SNES Function norm 9.417736022375e+01
#   5 SNES Function norm 2.730307902337e+01
#   6 SNES Function norm 7.552881132511e+00
#   7 SNES Function norm 1.819159029055e+00
#   8 SNES Function norm 3.010317537436e-01
#   9 SNES Function norm 1.940504371084e-02
#  10 SNES Function norm 7.629283389117e-02
#  11 SNES Function norm 2.030738066764e-02
#  12 SNES Function norm 4.647303690766e-03
#  13 SNES Function norm 6.982956508588e-04
#   0 SNES Function norm 9.660281497869e-02
#   1 SNES Function norm 8.614784274845e-01
#   2 SNES Function norm 1.664370045579e-01
#   3 SNES Function norm 1.981984201125e-02
#   4 SNES Function norm 9.613546803350e-04
#   5 SNES Function norm 8.181963115844e-06
#   6 SNES Function norm 1.314866876636e-09
#   0 SNES Function norm 6.187460704393e-03
#   1 SNES Function norm 9.359300012164e-02
#   2 SNES Function norm 1.614733921717e-02
#   3 SNES Function norm 2.013034450325e-03
#   4 SNES Function norm 8.786315123063e-05
#   5 SNES Function norm 3.626930281975e-07
#   0 SNES Function norm 2.059776114121e-03
#   1 SNES Function norm 1.050330310342e-01
#   2 SNES Function norm 2.415231700444e-02
#   3 SNES Function norm 4.594683171130e-03
#   4 SNES Function norm 4.155870361434e-04
#   5 SNES Function norm 5.132235450061e-06
#   6 SNES Function norm 8.385254896392e-10
#   0 SNES Function norm 1.441957449037e-03
#   1 SNES Function norm 6.111066170684e-02
#   2 SNES Function norm 1.024456362632e-02
#   3 SNES Function norm 8.487244089219e-04
#   4 SNES Function norm 1.044033378347e-05
#   5 SNES Function norm 1.872867108760e-09
#   0 SNES Function norm 1.228668350616e-03
#   1 SNES Function norm 1.209104085619e-01
#   2 SNES Function norm 3.058195750694e-02
#   3 SNES Function norm 5.990259640932e-03
#   4 SNES Function norm 4.743298701936e-04
#   5 SNES Function norm 3.814039224270e-06
#   6 SNES Function norm 2.518487222949e-10
#   0 SNES Function norm 9.888544308728e-04
#   1 SNES Function norm 1.645855007549e-02
#   2 SNES Function norm 1.082536304295e-03
#   3 SNES Function norm 2.920345689540e-05
#   4 SNES Function norm 6.547644724863e-08
#   0 SNES Function norm 9.023614909186e-04
#   1 SNES Function norm 7.252218051746e-02
#   2 SNES Function norm 1.635341438369e-02
#   3 SNES Function norm 2.550552851867e-03
#   4 SNES Function norm 2.759056003799e-04
#   5 SNES Function norm 2.413724994223e-04
#   6 SNES Function norm 3.242270719986e-05
#   7 SNES Function norm 2.271681875902e-06
#   8 SNES Function norm 1.233853725270e-08
#   0 SNES Function norm 9.937294444965e-04
#   1 SNES Function norm 8.064350695465e+00
#   2 SNES Function norm 2.381607695621e+00
#   3 SNES Function norm 7.011062598565e-01
#   4 SNES Function norm 2.042255014988e-01
#   5 SNES Function norm 5.748415019350e-02
#   6 SNES Function norm 1.457239654739e-02
#   7 SNES Function norm 2.645952506239e-03
#   8 SNES Function norm 1.713208467390e-04
#   9 SNES Function norm 8.831776637123e-07
#   0 SNES Function norm 1.093108166051e-03
#   1 SNES Function norm 1.686621578873e-01
#   2 SNES Function norm 4.423281295591e-02
#   3 SNES Function norm 9.246034681872e-03
#   4 SNES Function norm 8.887235083740e-04
#   5 SNES Function norm 1.138542100099e-05
#   6 SNES Function norm 1.942444979859e-09
#   0 SNES Function norm 7.728686961028e-04
#   1 SNES Function norm 1.754219728197e-01
#   2 SNES Function norm 4.854437018913e-02
#   3 SNES Function norm 1.208791759311e-02
#   4 SNES Function norm 2.049962632031e-03
#   5 SNES Function norm 1.086493667791e-04
#   6 SNES Function norm 3.597849956326e-07
#   0 SNES Function norm 6.393578693365e-04
#   1 SNES Function norm 1.423683065124e-02
#   2 SNES Function norm 1.210192280981e-03
#   3 SNES Function norm 8.070301531646e-05
#   4 SNES Function norm 1.029562822178e-06
#   5 SNES Function norm 1.529595190760e-10
#   0 SNES Function norm 6.525799044558e-04
#   1 SNES Function norm 2.206960276826e-01
#   2 SNES Function norm 6.114793141618e-02
#   3 SNES Function norm 1.528106206884e-02
#   4 SNES Function norm 2.769136677045e-03
#   5 SNES Function norm 1.871808584286e-04
#   6 SNES Function norm 1.090746497722e-06
#   0 SNES Function norm 6.537727634053e-04
#   1 SNES Function norm 1.554577216155e-02
#   2 SNES Function norm 1.327439767799e-03
#   3 SNES Function norm 2.195115155304e-05
#   4 SNES Function norm 9.011918912199e-09
#   0 SNES Function norm 4.905834750083e-04
#   1 SNES Function norm 4.465251867090e-03
#   2 SNES Function norm 5.276943907038e-05
#   3 SNES Function norm 4.857731324347e-08
#   0 SNES Function norm 4.212769074925e-04
#   1 SNES Function norm 3.766943602683e-03
#   2 SNES Function norm 1.084424009096e-04
#   3 SNES Function norm 2.308032229961e-06
#   4 SNES Function norm 1.362381669737e-09
#   0 SNES Function norm 4.261263383306e-04
#   1 SNES Function norm 1.712901076978e-02
#   2 SNES Function norm 3.174990193452e-03
#   3 SNES Function norm 2.797061757103e-04
#   4 SNES Function norm 2.941970599967e-06
#   5 SNES Function norm 3.440843777939e-10
#   0 SNES Function norm 4.627340031881e-04
#   1 SNES Function norm 1.615999402794e-02
#   2 SNES Function norm 2.555054782448e-03
#   3 SNES Function norm 1.675384437490e-04
#   4 SNES Function norm 1.032416287008e-06
#   0 SNES Function norm 4.024019757544e-04
#   1 SNES Function norm 4.520786924270e-03
#   2 SNES Function norm 2.512940190710e-04
#   3 SNES Function norm 4.214312360687e-05
#   4 SNES Function norm 2.145924370339e-06
#   5 SNES Function norm 5.029758443649e-09
#   0 SNES Function norm 3.983136337536e-04
#   1 SNES Function norm 3.415616459076e-01
#   2 SNES Function norm 9.871937549536e-02
#   3 SNES Function norm 2.799348830322e-02
#   4 SNES Function norm 7.146732670867e-03
#   5 SNES Function norm 1.382494910683e-03
#   6 SNES Function norm 1.122726617757e-04
#   7 SNES Function norm 9.897357820084e-07
#   0 SNES Function norm 4.853982030494e-04
#   1 SNES Function norm 3.155879298578e-02
#   2 SNES Function norm 6.279663011574e-03
#   3 SNES Function norm 6.227920995714e-04
#   4 SNES Function norm 9.195099485817e-06
#   5 SNES Function norm 2.148029220432e-09
#   0 SNES Function norm 3.894375126949e-04
#   1 SNES Function norm 4.421722993408e-03
#   2 SNES Function norm 8.454821088318e-05
#   3 SNES Function norm 6.394279811637e-08
#   0 SNES Function norm 3.339993101355e-04
#   1 SNES Function norm 3.509451805376e-03
#   2 SNES Function norm 6.496010240866e-05
#   3 SNES Function norm 4.709410495938e-08
#   0 SNES Function norm 3.101599413332e-04
#   1 SNES Function norm 3.482389873497e-03
#   2 SNES Function norm 7.831522813596e-05
#   3 SNES Function norm 9.900646920086e-08
#   0 SNES Function norm 2.968422906895e-04
#   1 SNES Function norm 3.045010257806e-03
#   2 SNES Function norm 5.389092220430e-05
#   3 SNES Function norm 2.894048194170e-08
#   0 SNES Function norm 2.873583684089e-04
#   1 SNES Function norm 2.716859118555e-03
#   2 SNES Function norm 4.392903872676e-05
#   3 SNES Function norm 2.181274313461e-08
#   0 SNES Function norm 2.781796011525e-04
#   1 SNES Function norm 2.375951412167e-03
#   2 SNES Function norm 3.779682590209e-05
#   3 SNES Function norm 3.013040524221e-08
#   0 SNES Function norm 2.697059998266e-04
#   1 SNES Function norm 1.899111144486e-03
#   2 SNES Function norm 1.716164468476e-05
#   3 SNES Function norm 2.751488987551e-09
#   0 SNES Function norm 2.670300549859e-04
#   1 SNES Function norm 1.759886575608e-03
#   2 SNES Function norm 1.360246448130e-05
#   3 SNES Function norm 1.883452134933e-09
#   0 SNES Function norm 2.721420078532e-04
#   1 SNES Function norm 2.028586675161e-03
#   2 SNES Function norm 3.227989483194e-05
#   3 SNES Function norm 2.506106294787e-08
#   0 SNES Function norm 2.883548791185e-04
#   1 SNES Function norm 3.090162197154e-03
#   2 SNES Function norm 2.296590143807e-04
#   3 SNES Function norm 4.388056625024e-06
#   4 SNES Function norm 2.703286934240e-09
#   0 SNES Function norm 3.433699970302e-04
#   1 SNES Function norm 9.638597186841e-03
#   2 SNES Function norm 3.166736491921e-03
#   3 SNES Function norm 3.382306450109e-04
#   4 SNES Function norm 8.391458714660e-06
#   5 SNES Function norm 5.707171392112e-09
#   0 SNES Function norm 6.270617703416e-04
#   1 SNES Function norm 7.815515625876e-02
#   2 SNES Function norm 1.738507520976e-02
#   3 SNES Function norm 2.336869600300e-03
#   4 SNES Function norm 7.282015944695e-05
#   5 SNES Function norm 7.895322641270e-08
#   0 SNES Function norm 5.840105953848e-04
#   1 SNES Function norm 2.120280149142e-02
#   2 SNES Function norm 2.730140637329e-03
#   3 SNES Function norm 8.470967641762e-05
#   4 SNES Function norm 9.254555721521e-08
#   0 SNES Function norm 3.493466815286e-04
#   1 SNES Function norm 2.544907879910e-03
#   2 SNES Function norm 2.418500563190e-05
#   3 SNES Function norm 4.574647233623e-09
#   0 SNES Function norm 2.495881596069e-04
#   1 SNES Function norm 1.000053235875e-03
#   2 SNES Function norm 1.797608937459e-06
#   3 SNES Function norm 2.586507771812e-11
#   0 SNES Function norm 2.113658466652e-04
#   1 SNES Function norm 8.072141975028e-04
#   2 SNES Function norm 1.813210842744e-06
#   3 SNES Function norm 3.981094665187e-11
#   0 SNES Function norm 1.961397944217e-04
#   1 SNES Function norm 7.933174003440e-04
#   2 SNES Function norm 2.164891931013e-06
#   3 SNES Function norm 7.031918994820e-11
#   0 SNES Function norm 1.903296244742e-04
#   1 SNES Function norm 8.119203019284e-04
#   2 SNES Function norm 2.767211345209e-06
#   3 SNES Function norm 1.401464958119e-10
#   0 SNES Function norm 1.886509987332e-04
#   1 SNES Function norm 8.521233150769e-04
#   2 SNES Function norm 3.819921121363e-06
#   3 SNES Function norm 3.118288297466e-10
#   0 SNES Function norm 1.891982051359e-04
#   1 SNES Function norm 9.270666437428e-04
#   2 SNES Function norm 5.837932434070e-06
#   3 SNES Function norm 8.601959886032e-10
#   0 SNES Function norm 1.917137055526e-04
#   1 SNES Function norm 1.067237090891e-03
#   2 SNES Function norm 1.087359958918e-05
#   3 SNES Function norm 3.789289277639e-09
#   0 SNES Function norm 1.973234815774e-04
#   1 SNES Function norm 1.360206651026e-03
#   2 SNES Function norm 2.986532896065e-05
#   3 SNES Function norm 4.161508497826e-08
#   0 SNES Function norm 2.098881439272e-04
#   1 SNES Function norm 2.195739245290e-03
#   2 SNES Function norm 1.809450777940e-04
#   3 SNES Function norm 3.686504497166e-06
#   4 SNES Function norm 1.560411907926e-09
#   0 SNES Function norm 2.526241382278e-04
#   1 SNES Function norm 7.541195562574e-03
#   2 SNES Function norm 5.492628687410e-04
#   3 SNES Function norm 8.251019762142e-06
#   4 SNES Function norm 2.832823926585e-09
#   0 SNES Function norm 3.846158608172e-04
#   1 SNES Function norm 2.020099301289e-02
#   2 SNES Function norm 3.389815253461e-03
#   3 SNES Function norm 1.837064936320e-04
#   4 SNES Function norm 6.520437444758e-07
#   0 SNES Function norm 2.773345565902e-04
#   1 SNES Function norm 2.542672066873e-03
#   2 SNES Function norm 6.812511646819e-05
#   3 SNES Function norm 2.774419721520e-07
#   0 SNES Function norm 2.326992393919e-04
#   1 SNES Function norm 2.865060482162e-03
#   2 SNES Function norm 7.239125355770e-04
#   3 SNES Function norm 5.638145129097e-05
#   4 SNES Function norm 5.241244492499e-07
#   5 SNES Function norm 5.540340818469e-11
#   0 SNES Function norm 3.136598999901e-04
#   1 SNES Function norm 1.113099599007e-01
#   2 SNES Function norm 3.023398004022e-02
#   3 SNES Function norm 6.901272328516e-03
#   4 SNES Function norm 9.031625070454e-04
#   5 SNES Function norm 2.482129326189e-05
#   6 SNES Function norm 2.052322316821e-08
#   0 SNES Function norm 2.705001796824e-04
#   1 SNES Function norm 3.555804660196e-03
#   2 SNES Function norm 1.189949846858e-04
#   3 SNES Function norm 2.208895518255e-07
#   0 SNES Function norm 2.087270077616e-04
#   1 SNES Function norm 9.665627001368e-04
#   2 SNES Function norm 2.580558653662e-06
#   3 SNES Function norm 5.955449764896e-11
#   0 SNES Function norm 1.888944735258e-04
#   1 SNES Function norm 6.628716332125e-04
#   2 SNES Function norm 9.346905892589e-07
#   3 SNES Function norm 1.372126506284e-11
#   0 SNES Function norm 1.815635958970e-04
#   1 SNES Function norm 6.588978145989e-04
#   2 SNES Function norm 1.528863718072e-06
#   3 SNES Function norm 1.283094185954e-10
#   0 SNES Function norm 1.813443470884e-04
#   1 SNES Function norm 7.684961662737e-04
#   2 SNES Function norm 6.553425431681e-06
#   3 SNES Function norm 5.889272554069e-09
#   0 SNES Function norm 1.897031395393e-04
#   1 SNES Function norm 1.351804457841e-03
#   2 SNES Function norm 7.260670505176e-05
#   3 SNES Function norm 1.115340160656e-07
#   0 SNES Function norm 2.408127558477e-04
#   1 SNES Function norm 2.302321010693e-02
#   2 SNES Function norm 4.953378798558e-03
#   3 SNES Function norm 7.132365942919e-04
#   4 SNES Function norm 2.560133396493e-05
#   5 SNES Function norm 3.681068206919e-08
#   0 SNES Function norm 3.173838840188e-04
#   1 SNES Function norm 1.024965291878e-02
#   2 SNES Function norm 1.124932453629e-03
#   3 SNES Function norm 2.522119791231e-05
#   4 SNES Function norm 1.374936513650e-08
#   0 SNES Function norm 3.138178579140e-04
#   1 SNES Function norm 4.798246556071e-03
#   2 SNES Function norm 1.295081483075e-04
#   3 SNES Function norm 1.611918439268e-07
#   0 SNES Function norm 3.199776071558e-04
#   1 SNES Function norm 4.781409791427e-03
#   2 SNES Function norm 1.395561272251e-04
#   3 SNES Function norm 3.447293376936e-07
#   0 SNES Function norm 3.438265175364e-04
#   1 SNES Function norm 6.235511837831e-03
#   2 SNES Function norm 1.047975914580e-03
#   3 SNES Function norm 1.006147448220e-04
#   4 SNES Function norm 1.297019740325e-06
#   5 SNES Function norm 2.456323991419e-10
#   0 SNES Function norm 4.979474976367e-04
#   1 SNES Function norm 2.216018730387e-01
#   2 SNES Function norm 6.189342106179e-02
#   3 SNES Function norm 1.505851616447e-02
#   4 SNES Function norm 2.273955021126e-03
#   5 SNES Function norm 8.789944926818e-05
#   6 SNES Function norm 1.486446834082e-07
#   0 SNES Function norm 5.985983097150e-04
#   1 SNES Function norm 1.079768188092e-01
#   2 SNES Function norm 2.742371020708e-02
#   3 SNES Function norm 4.979961025109e-03
#   4 SNES Function norm 3.199498044712e-04
#   5 SNES Function norm 1.630838694184e-06
#   6 SNES Function norm 4.303654562767e-11
#   0 SNES Function norm 4.256253975773e-04
#   1 SNES Function norm 5.221027602694e-03
#   2 SNES Function norm 1.260515493358e-04
#   3 SNES Function norm 1.353647544941e-07
#   0 SNES Function norm 3.025383747118e-04
#   1 SNES Function norm 2.484692462380e-03
#   2 SNES Function norm 1.368518739280e-04
#   3 SNES Function norm 1.923904648764e-07
#   0 SNES Function norm 3.043595840249e-04
#   1 SNES Function norm 3.595952630464e-02
#   2 SNES Function norm 8.639870287749e-03
#   3 SNES Function norm 1.468144584538e-03
#   4 SNES Function norm 7.948455895521e-05
#   5 SNES Function norm 2.757438597819e-07
#   0 SNES Function norm 3.377727016497e-04
#   1 SNES Function norm 8.220045339193e-03
#   2 SNES Function norm 7.674071240917e-04
#   3 SNES Function norm 1.065100445689e-05
#   4 SNES Function norm 2.136060108631e-09
#   0 SNES Function norm 2.918970985938e-04
#   1 SNES Function norm 3.001751389332e-03
#   2 SNES Function norm 6.052312342308e-05
#   3 SNES Function norm 4.411881076750e-08
#   0 SNES Function norm 2.643845798185e-04
#   1 SNES Function norm 2.181852284463e-03
#   2 SNES Function norm 3.588495097248e-05
#   3 SNES Function norm 4.256935259366e-08
#   0 SNES Function norm 2.602091371776e-04
#   1 SNES Function norm 2.868218442206e-03
#   2 SNES Function norm 3.240568894282e-04
#   3 SNES Function norm 1.179307968862e-05
#   4 SNES Function norm 1.606868761623e-08
#   0 SNES Function norm 3.086856577100e-04
#   1 SNES Function norm 1.376715499017e-02
#   2 SNES Function norm 1.145574839216e-03
#   3 SNES Function norm 2.828582381129e-05
#   4 SNES Function norm 2.486491956356e-08
#   0 SNES Function norm 4.826329563231e-04
#   1 SNES Function norm 2.374511869426e-02
#   2 SNES Function norm 3.475398651628e-03
#   3 SNES Function norm 1.411041593501e-04
#   4 SNES Function norm 2.707040412098e-07
#   0 SNES Function norm 3.242249109526e-04
#   1 SNES Function norm 3.294603759673e-03
#   2 SNES Function norm 2.535334898948e-04
#   3 SNES Function norm 1.348332568245e-05
#   4 SNES Function norm 4.187630317717e-08
#   0 SNES Function norm 2.787005569328e-04
#   1 SNES Function norm 1.717692765742e-02
#   2 SNES Function norm 2.764587427907e-03
#   3 SNES Function norm 2.110149380247e-04
#   4 SNES Function norm 2.278245429823e-06
#   5 SNES Function norm 3.086098972882e-10
#   0 SNES Function norm 3.328428837407e-04
#   1 SNES Function norm 1.188856551176e-02
#   2 SNES Function norm 1.399399181561e-03
#   3 SNES Function norm 3.577321539750e-05
#   4 SNES Function norm 2.745992540994e-08
#   0 SNES Function norm 2.308682127316e-04
#   1 SNES Function norm 1.794936054377e-03
#   2 SNES Function norm 1.433122153352e-05
#   3 SNES Function norm 2.095569289871e-09
#   0 SNES Function norm 1.911157468704e-04
#   1 SNES Function norm 1.143931952022e-03
#   2 SNES Function norm 5.671583117819e-06
#   3 SNES Function norm 3.200337843902e-10
#   0 SNES Function norm 1.746460230646e-04
#   1 SNES Function norm 1.039535277586e-03
#   2 SNES Function norm 5.305491723253e-06
#   3 SNES Function norm 2.784181391759e-10
#   0 SNES Function norm 1.653588038328e-04
#   1 SNES Function norm 9.578323227929e-04
#   2 SNES Function norm 4.553546124461e-06
#   3 SNES Function norm 1.787567472803e-10
#   0 SNES Function norm 1.591652869486e-04
#   1 SNES Function norm 8.914824516564e-04
#   2 SNES Function norm 4.003248160017e-06
#   3 SNES Function norm 1.492889847030e-10
#   0 SNES Function norm 1.544804484038e-04
#   1 SNES Function norm 8.453751512529e-04
#   2 SNES Function norm 3.597692113040e-06
#   3 SNES Function norm 1.283703259094e-10
#   0 SNES Function norm 1.505015279481e-04
#   1 SNES Function norm 8.042705106652e-04
#   2 SNES Function norm 3.232044574344e-06
#   3 SNES Function norm 9.948305662041e-11
#   0 SNES Function norm 1.468837260908e-04
#   1 SNES Function norm 7.618585775406e-04
#   2 SNES Function norm 2.935110343839e-06
#   3 SNES Function norm 7.486636845237e-11
#   0 SNES Function norm 1.432767155088e-04
#   1 SNES Function norm 7.228986825681e-04
#   2 SNES Function norm 2.721707544442e-06
#   3 SNES Function norm 6.817966583931e-11
#   0 SNES Function norm 1.391670953040e-04
#   1 SNES Function norm 6.822254395111e-04
#   2 SNES Function norm 2.444673590400e-06
#   3 SNES Function norm 6.230924214592e-11
#   0 SNES Function norm 1.343229605211e-04
#   1 SNES Function norm 6.304139769524e-04
#   2 SNES Function norm 1.985316797743e-06
#   3 SNES Function norm 3.817910798085e-11
#   0 SNES Function norm 1.290518125872e-04
#   1 SNES Function norm 5.709696901789e-04
#   2 SNES Function norm 1.515997254685e-06
#   3 SNES Function norm 1.883396087484e-11
#   0 SNES Function norm 1.238678279078e-04
#   1 SNES Function norm 5.123897697973e-04
#   2 SNES Function norm 1.178677054584e-06
#   0 SNES Function norm 1.191464932236e-04
#   1 SNES Function norm 4.603314030338e-04
#   2 SNES Function norm 9.522076537270e-07
#   0 SNES Function norm 1.150279421433e-04
#   1 SNES Function norm 4.173745284512e-04
#   2 SNES Function norm 7.864254444822e-07
#   0 SNES Function norm 1.115229261614e-04
#   1 SNES Function norm 3.836763304143e-04
#   2 SNES Function norm 6.569715226774e-07
#   0 SNES Function norm 1.085727056766e-04
#   1 SNES Function norm 3.575676595443e-04
#   2 SNES Function norm 5.538580813927e-07
#   0 SNES Function norm 1.061168076515e-04
#   1 SNES Function norm 3.366070891485e-04
#   2 SNES Function norm 4.702000428419e-07
#   0 SNES Function norm 1.041082037123e-04
#   1 SNES Function norm 3.190830108241e-04
#   2 SNES Function norm 4.027057864109e-07
#   0 SNES Function norm 1.024900087189e-04
#   1 SNES Function norm 3.046004376040e-04
#   2 SNES Function norm 3.508273255825e-07
#   0 SNES Function norm 1.011631399320e-04
#   1 SNES Function norm 2.932608097002e-04
#   2 SNES Function norm 3.152731851813e-07
#   0 SNES Function norm 9.998126920810e-05
#   1 SNES Function norm 2.842964363589e-04
#   2 SNES Function norm 2.964957637892e-07
#   0 SNES Function norm 9.879056372898e-05
#   1 SNES Function norm 2.756501242640e-04
#   2 SNES Function norm 2.856901508923e-07
#   0 SNES Function norm 9.749187495703e-05
#   1 SNES Function norm 2.653688463743e-04
#   2 SNES Function norm 2.647788267730e-07
#   0 SNES Function norm 9.607334889162e-05
#   1 SNES Function norm 2.531448974491e-04
#   2 SNES Function norm 2.291593920846e-07
